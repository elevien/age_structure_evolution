# %%
import numpy as np
import matplotlib.pyplot as plt
import copy,sys,os
import pandas as pd

# %config InlineBackend.figure_format = "svg"
import matplotlib as mpl

mpl.rcParams['axes.spines.right'] = False
mpl.rcParams['axes.spines.top'] = False

from sims.models import *
import sims.evolutionary_dynamics as ED

# %%
fig,ax = plt.subplots(figsize=(5,2))

N = 10**4
tmax = 10
params = 1
cells_init = ED.make_cells_init(0.4,N,divide_markov,params);
t,n,cells = ED.moran_rgt(tmax,divide_markov,cells_init,div_params=params)
ax.plot(t,n)

t,n,cells = ED.moran_rgt(tmax,divide_markov,cells_init,div_params=params)
ax.plot(t,n)

t,n,cells = ED.moran_rgt(tmax,divide_markov,cells_init,div_params=params)
ax.plot(t,n)


ax.set_xlabel("time")
ax.set_ylabel("mutant number")
# Out:
# Text(0, 0.5, 'mutant number')
